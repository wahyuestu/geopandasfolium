# %%
#Link youtube tutorial pengerjaan : https://youtu.be/1u6mXXqD51E
#Link mengambil data peta : https://tanahair.indonesia.go.id/unduh-rbi/#/
#Link converter to geojson/json : mapshaper.org

# %%
pip install geodatasets #digunakan untuk menginstal paket Python bernama "geodatasets" dari Python Package Index (PyPI)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#digunakan'
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings
warnings.filterwarnings('ignore') #Untuk memberi tahu Python untuk mengabaikan pemberitahuan yang akan datang selama eksekusi program.

# %%
pip install geopandas #untuk menginstall library geopandas

# %%
import geopandas as gpd #Untuk memasukkan modul geopandas dengan menggunakan alias gpd.

# %%
gdf = gpd.read_file("RBI25K_ADMINISTRASI_AR.geojson") #digunakan untuk membaca data geospasial dari file dengan format GeoJSON/Json
gdf.head() #Digunakan untuk menampilkan beberapa baris pertama dari GeoDataFrame. Fungsi head() umumnya digunakan untuk memberikan gambaran cepat tentang struktur dan isi dari GeoDataFrame atau DataFrame
# gdf.info()
# Out:
#             NAMOBJ       FCODE REMARK                                METADATA  \
# 0           Batang  BA03040060   None  TASWIL2500020210531_DATA_BATAS_KABKOTA
# 1       Pekalongan  BA03040060   None  TASWIL2500020210531_DATA_BATAS_KABKOTA
# 2  Kota Pekalongan  BA03040060   None  TASWIL2500020210531_DATA_BATAS_KABKOTA
#
#   SRS_ID KDBBPS KDCBPS KDCPUM KDEBPS KDEPUM  ... WADMKD           WADMKK  \
# 0   None   None   None   None   None   None  ...   None           Batang
# 1   None   None   None   None   None   None  ...   None       Pekalongan
# 2   None   None   None   None   None   None  ...   None  Kota Pekalongan
#
#         WADMPR  WIADKC  WIADKK WIADPR WIADKD SHAPE_AREA SHAPE_LEN  \
# 0  Jawa Tengah    None    None   None      0   0.070157  1.531137
# 1  Jawa Tengah    None    None   None      0   0.073080  1.703640
# 2  Jawa Tengah    None    None   None      0   0.003780  0.415770
#
#                                             geometry
# ...

# %%
gdf = gdf[['NAMOBJ', 'FCODE', 'SHAPE_AREA', 'SHAPE_LEN', 'geometry']].fillna(0) #digunakan untuk membuat subset dari GeoDataFrame yang hanya memuat kolom-kolom yang ingin dimasukkan

# %%
pip install folium matplotlib mapclassify #untuk menginstall library folium (pembuatan peta interaktif menggunakan Leaflet.js.), matplotlib (library untuk membuat visualisasi statis dan dinamis di Python), mapclassify (library yang menyediakan alat untuk klasifikasi data spasial)
# Out:
#   Cell In[6], line 1
#     pip install folium matplotlib mapclassify
#         ^
# SyntaxError: invalid syntax

# %%
import folium #memasukkan library folium
m = gdf.explore(column="SHAPE_AREA", name="Shape Area") #m adalah variabel, gdf (untuk memberikan warna pada elemen peta), explore (untuk menampilkan visual peta dari data geospasial)
folium.LayerControl().add_to(m) #memungkinkan pengguna untuk mengonfigurasi tampilan peta dengan memilih lapisan yang ingin ditampilkan 
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
